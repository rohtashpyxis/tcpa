# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# %%
datas = pd.read_csv('hello_fresh - Sheetmeal.csv')
datas
datas = datas.rename({'Date & time':'date'}, axis = 1)
datas['date'] = pd.to_datetime(datas['date']).dt.strftime("%y-%m-%d")
# datas = datas.drop(['Date & time'], axis=1)

# %%
def get_tcpa_range(data):

  initial = []
  final = []
  dates = []
  campaigns = []
  ad_group = []
  # data["Changes"]
  level = []
  # data["Date & time"]
  # print(type(data["Changes"]))
  for i in range(len(data["Changes"])):
    if "Target CPA" in data["Changes"][i]:
      # print(i)
      # print(data["Changes"][i])
      # print(data["Date & time"][i])
      dates.append(data["date"][i])
      campaigns.append(data["Campaign"][i])
      ad_group.append(data["Ad group"][i])
      

    
      if "Campaign" in data["Changes"][i]:
        level.append("campaign")

      else:
        level.append("ad group")
    
      # print((i))
      k = data["Changes"][i].split(" ")
      # print(i)
    
      for j in k:
        if "to" == j:
          initial.append(float(k[k.index(j)-1].replace("$","")))
          final.append(float(k[k.index(j)+1].replace("$","")))
        
    
  df= pd.DataFrame()
  df["date"]= dates
  df["initial"] = initial
  df["final"] = final
  df["level"] = level
  df["Campaign name"]= campaigns
  df["Ad group name"] = ad_group
  
  return df

# %%
tcpa = get_tcpa_range(datas)
df= tcpa 
# df
tcpa
# Out:
#         date  initial  final     level  \
# 0   22-07-05    120.0  126.0  ad group
# 1   22-07-04    111.0  120.0  ad group
# 2   22-06-28     99.0  105.0  campaign
# 3   22-06-03    107.0  111.0  ad group
# 4   22-06-03     99.0  107.0  ad group
# 5   22-05-31     95.0   99.0  campaign
# 6   22-05-17    105.0   95.0  campaign
# 7   22-05-17     95.0  105.0  campaign
# 8   22-05-17     93.0   95.0  campaign
# 9   22-05-14     80.0   93.0  campaign
# 10  22-05-10     85.0   80.0  campaign
# 11  22-04-30     93.0   99.0  ad group
# 12  22-04-27     90.0   85.0  campaign
# 13  22-04-23     85.0   90.0  campaign
# 14  22-04-21     80.0   85.0  campaign
# 15  22-04-20     85.0   93.0  ad group
# 16  22-04-18     83.0   85.0  ad group
# 17  22-04-17     75.0   83.0  ad group
# 18  22-04-17     55.0   75.0  ad group
# 19  22-04-16     51.0   55.0  ad group
# 20  22-04-12     36.0   51.0  ad group
# 21  22-03-31     70.0   80.0  campaign
# 22  22-02-15     50.0   70.0  campaign
# 23  22-01-10     75.0   50.0  campaign
#
#                                     Campaign name Ad group name
# 0   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 1   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 2   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 3   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 4   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 5   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 6   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 7   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 8   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 9   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 10  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 11  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 12  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 13  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 14  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 15  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 16  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 17  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 18  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 19  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 20  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 21  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 22  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 23  US-S[01]: Prospecting | Brand | Meals - Exact           NaN

# %%
data = pd.read_csv('TCPA strategy - Hellofresh-metric.csv')
data.rename(columns={'Date':'date','Ad group ID':'ad_group_id','Campaign ID':'campaign_id','Cost':'cost','Keyword ID':'keyword_id','Cost per conversion':'cost_per_conversion','Conversions':'conversions','Clicks':'clicks','Impressions':'impressions','Impression share':'impression_share','Keyword':'keyword'},inplace=True)


data_meals = data[data["Campaign name"]== "US-S[01]: Prospecting | Brand | Meals - Exact"].copy()
data_meals['date'] = pd.to_datetime(data_meals['date']).dt.strftime("%y-%m-%d")

# %%
# tcpa
tcpa = tcpa[tcpa["level"]== "campaign"]
tcpa
# Out:
#         date  initial  final     level  \
# 2   22-06-28     99.0  105.0  campaign
# 5   22-05-31     95.0   99.0  campaign
# 6   22-05-17    105.0   95.0  campaign
# 7   22-05-17     95.0  105.0  campaign
# 8   22-05-17     93.0   95.0  campaign
# 9   22-05-14     80.0   93.0  campaign
# 10  22-05-10     85.0   80.0  campaign
# 12  22-04-27     90.0   85.0  campaign
# 13  22-04-23     85.0   90.0  campaign
# 14  22-04-21     80.0   85.0  campaign
# 21  22-03-31     70.0   80.0  campaign
# 22  22-02-15     50.0   70.0  campaign
# 23  22-01-10     75.0   50.0  campaign
#
#                                     Campaign name Ad group name
# 2   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 5   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 6   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 7   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 8   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 9   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 10  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 12  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 13  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 14  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 21  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 22  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 23  US-S[01]: Prospecting | Brand | Meals - Exact           NaN

# %%
data1 = pd.merge(data_meals,tcpa,on=['date'], how = "left")
data1["final"].fillna(method ="ffill", inplace = True)
# df.fillna(method='ffill')

# %%
count = 0
for i in tcpa['final']:
  count = count+1
  # print(i)
  data = data1[data1["final"] == i]
  # print(data)
  #find top ad_groups basis spends
  analysis = data.groupby(['ad_group_id'])['cost'].sum().reset_index().sort_values('cost',ascending=False,ignore_index = True)
  analysis["Cost_cumsum"] = analysis["cost"].cumsum()
  analysis["cost_share"] = analysis["cost"].cumsum()/analysis['cost'].sum()


  #take top 10 adgroups
  top_adgroups = analysis[:10]['ad_group_id'].values
  # print(top_adgroups)


  df = data[data['ad_group_id'].isin(top_adgroups)].copy()

  analysis = df.groupby('ad_group_id')[['final','cost','conversions','impression_share',"clicks"]].agg({'final':'mean','cost':'sum','conversions':'sum','impression_share':'mean',"clicks":"sum",})
  analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']
  if count == 1:
    new = analysis
  new = pd.concat([new, analysis])
new = new.iloc[1:,:]
print(new)
# Out:
#               final       cost  conversions  impression_share  clicks  \
# ad_group_id
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   99.0  174444.49      1461.25          0.918219   35849
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183   93.0   23347.30       226.59          0.914348    4407
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   90.0   24564.24       237.55          0.887821    5427
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   70.0   49320.80      1290.68          0.756044   27953
# 104499295183   50.0   29763.93       912.44          0.816783   22565
#
#               cost_per_conv
# ad_group_id
# 104499295183     117.764781
# 104499295183     119.380318
# 104499295183      96.549223
# 104499295183     117.764781
# 104499295183      96.549223
# 104499295183     103.037645
# 104499295183      75.317866
# 104499295183     103.061015
# 104499295183     103.406609
# 104499295183     103.061015
# 104499295183      75.317866
# 104499295183      38.213035
# 104499295183      32.620150

# %%
 new["cost_per_conv_delta"] = new["cost_per_conv"].diff() 
 new["clicks_delta"] = new["clicks"].diff()
 new["impression_share_delta"] = new["impression_share"].diff()
new["conversions_delta"] = new["conversions"].diff()
new
# Out:
#               final       cost  conversions  impression_share  clicks  \
# ad_group_id
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   99.0  174444.49      1461.25          0.918219   35849
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183   93.0   23347.30       226.59          0.914348    4407
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   90.0   24564.24       237.55          0.887821    5427
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   70.0   49320.80      1290.68          0.756044   27953
# 104499295183   50.0   29763.93       912.44          0.816783   22565
#
#               cost_per_conv  cost_per_conv_delta  clicks_delta  \
# ad_group_id
# 104499295183     117.764781                  NaN           NaN
# 104499295183     119.380318             1.615537       25343.0
# 104499295183      96.549223           -22.831095      -18838.0
# 104499295183     117.764781            21.215558       -6505.0
# 104499295183      96.549223           -21.215558        6505.0
# 104499295183     103.037645             6.488422      -12604.0
# 104499295183      75.317866           -27.719779       16090.0
# 104499295183     103.061015            27.743149       -1390.0
# 104499295183     103.406609             0.345594      -13680.0
# 104499295183     103.061015            -0.345594       13680.0
# 104499295183      75.317866           -27.743149        1390.0
# 104499295183      38.213035           -37.104831        7456.0
# 104499295183      32.620150            -5.592885       -5388.0
#
#               impression_share_delta  conversions_delta
# ad_group_id
# 104499295183                     NaN                NaN
# 104499295183                0.003045            1053.97
# 104499295183                0.013136            -634.50
# 104499295183               -0.016181            -419.47
# 104499295183                0.016181             419.47
# 104499295183               -0.017007            -600.16
# 104499295183               -0.083445             703.74
# 104499295183                0.086227             -17.93
# 104499295183               -0.029309            -674.85
# 104499295183                0.029309             674.85
# 104499295183               -0.086227              17.93
# 104499295183               -0.074859             360.35
# 104499295183                0.060739            -378.24

# %%
import seaborn as sns

# %% [markdown]
# # average level graphs
# ### cost ka graph ad krana h
# ##  average cost_per_conv vs tcpa (reg plot from sns) (remove outlier)
# ## average cost_per_conv vs clicks
# ## average cost_per_conv vs  impression  share
# ## average cost_per_conv vs  conversion
# ## clicks vs conversion
# ## delta graphs average wise
# ## cpa vs conversions
# ### cpa vs cliks
# ###
# ## delta at date level

# %%
#grpah plot for this 

# sns.regplot(x= "cost_per_conv", y= "impression_share", data= analysis, order = 2)
sns.regplot(x='final',y='cost_per_conv', data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='final', ylabel='cost_per_conv'>

# %%
sns.regplot(x='final',y='conversions',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='final', ylabel='conversions'>

# %%
sns.regplot(x='final',y='cost', data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='final', ylabel='cost'>

# %%
sns.regplot(x='final',y='impression_share',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='final', ylabel='impression_share'>

# %% [markdown]
# # cost_per_conv vs

# %%
print(sns.regplot(x='cost_per_conv',y='impression_share',  data = new , order = 2))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.regplot(x='cost_per_conv',y='clicks',  data = new , order = 2))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.regplot(x='cost_per_conv',y='conversions',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv', ylabel='conversions'>

# %%
sns.regplot(x='cost_per_conv',y='clicks',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv', ylabel='clicks'>

# %%
sns.regplot(x='impression_share',y='clicks',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='impression_share', ylabel='clicks'>

# %%
sns.regplot(x='clicks',y='conversions',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='clicks', ylabel='conversions'>

# %% [markdown]
# # delta average graphs

# %%
sns.regplot(x='cost_per_conv_delta',y='impression_share_delta',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv_delta', ylabel='impression_share_delta'>

# %%
sns.regplot(x='cost_per_conv_delta',y='clicks_delta',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv_delta', ylabel='clicks_delta'>

# %%
sns.regplot(x='cost_per_conv_delta',y='conversions_delta',  data = new , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv_delta', ylabel='conversions_delta'>

# %% [markdown]
# # for sensitivity check
#
# data1

# %%
# data1

# %%
# data1["final"]

analysis = data1.groupby(['date','ad_group_id'])[['cost','conversions','final','clicks','impressions','impression_share',"Absolute top impression percentage"]].agg({'cost':'sum','conversions':'sum','final':'mean','clicks':'sum','impressions':'sum','impression_share':'mean', "Absolute top impression percentage":"mean"}).reset_index()
analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']
analysis['cost_per_click'] = analysis['cost']/analysis['clicks']

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "clicks", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "conversions", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "cost_per_conv", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
       analysis[analysis["final"]==i].plot(x= "cost_per_conv", y= "clicks", kind = "scatter",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "cost_per_conv", y= "impression_share", kind = "scatter",figsize=(10,5),title = i)

# %% [markdown]
# # date wise graphs

# %%
import seaborn as sns
analysis
# Out:
#          date   ad_group_id     cost  conversions  final  clicks  impressions  \
# 0    22-01-01  104499295183  2240.03        85.67    NaN    1337         3392
# 1    22-01-02  104499295183  2695.06        77.57    NaN    1502         3849
# 2    22-01-03  104499295183  3143.83       109.05    NaN    1773         4591
# 3    22-01-04  104499295183  3411.84        83.24    NaN    1943         4938
# 4    22-01-05  104499295183  3061.98        89.91    NaN    1804         4460
# ..        ...           ...      ...          ...    ...     ...          ...
# 182  22-07-02  104499295183  5381.06        54.85  105.0    1113         2475
# 183  22-07-03  104499295183  4652.05        44.25  105.0    1027         2240
# 184  22-07-04  104499295183  3955.12        32.65  105.0     963         2170
# 185  22-07-05  104499295183  4877.44        35.49  105.0    1102         2459
# 186  22-07-06  104499295183   508.12         1.00  105.0     114          260
#
#      impression_share  Absolute top impression percentage  cost_per_conv  \
# 0            0.854118                            0.529412      26.147193
# 1            0.831250                            0.636875      34.743586
# 2            0.861111                            0.432778      28.829253
# 3            0.903333                            0.513889      40.987987
# 4            0.909412                            0.527647      34.056056
# ..                ...                                 ...            ...
# 182          0.920909                            0.922727      98.105014
# 183          0.874500                            0.786190     105.131073
# 184          0.920435                            0.697826     121.136907
# 185          0.933043                            0.925600     137.431389
# 186               NaN                            0.851429     508.120000
#
#      cost_per_click
# 0          1.675415
# 1          1.794314
# 2          1.773170
# 3          1.755965
# 4          1.697328
# ..              ...
# 182        4.834735
# 183        4.529747
# 184        4.107082
# 185        4.425989
# 186        4.457193
#
# [187 rows x 11 columns]

# %%
#  analysis.plot(x= "cost_per_conv", y= "impression_share", kind = "scatter",figsize=(10,5))
sns.regplot(x= "cost_per_conv", y= "impression_share", data= analysis[analysis["cost_per_conv"]<300] , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv', ylabel='impression_share'>

# %%
#impression share some range and its has some saturaton value, (at cpa 50 impression share (.8 to .9)) and 
##(100-150 cpa impression share >.9

# %%
# data1

# %%
# analysis = df['rpb']
# analysis.index = pd.to_datetime(analysis.index)
# decompose_result_mult = seasonal_decompose(analysis, model="additive")
# plt.rcParams.update({'figure.figsize': (18,10)})
# decompose_result_mult.plot()

# %%
# tcpa["final"].hist()
data1["final"].hist()

# %%
sns.regplot(x= "cost_per_conv", y= "clicks", data= analysis[(analysis["cost_per_conv"]<300) &( analysis["clicks"]<3000)], order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv', ylabel='clicks'>

# %%
# analysis
analysis[analysis["cost_per_conv"]<300]

# %%
sns.regplot(x= "cost_per_conv", y= "Absolute top impression percentage", data= analysis[analysis["cost_per_conv"]<300], order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv', ylabel='Absolute top impression percentage'>

# %%
sns.regplot(x= "cost_per_conv", y= "conversions", data= analysis[(analysis["cost_per_conv"]<300) & (analysis["conversions"]<150)], order = 2)

# %%
# data1.info()

# %%
sns.regplot(y= "impression_share", x = "cost_per_click", data= analysis[(analysis["cost_per_conv"]<300)] , order = 2)

# %%
sns.regplot(y= "Absolute top impression percentage", x = "cost_per_click", data= analysis[(analysis["cost_per_conv"]<300)] , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_click', ylabel='Absolute top impression percentage'>

# %%
sns.regplot(y= "impression_share", x = "cost_per_click", data= analysis[(analysis["cost_per_conv"]<300)] , order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_click', ylabel='impression_share'>

# %%
sns.regplot(x= "cost_per_conv", y= "conversions", data= analysis[(analysis["cost_per_conv"]<200) ], order = 2)
# Out:
# <AxesSubplot:xlabel='cost_per_conv', ylabel='conversions'>

# %%
 analysis[analysis["cost_per_conv"]<250].plot(y= "cost_per_conv", x= "final", kind = "scatter",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='final', ylabel='cost_per_conv'>

# %%
# import matplotlib.pyplot as plt
# _,ax=plt.subplot(figsize = (18,3))
sns.boxplot(y= "cost_per_conv", x= "final", data =  analysis, width=.8 )
# Out:
# <AxesSubplot:xlabel='final', ylabel='cost_per_conv'>

# %%
analysis["final"].hist()
# Out:
# <AxesSubplot:>

# %%
ax= analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "final", figsize = (18,3))
analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "impression_share",ax=ax, secondary_y =True) 


# analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "Absolute top impression percentage",ax=ax, secondary_y =True)
# analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "cost",ax=ax, secondary_y =True)
# Out:
# <AxesSubplot:>

# %%
ax= analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "final", figsize = (18,3))
analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "conversions",ax=ax, secondary_y =True)
# Out:
# <AxesSubplot:>

# %%
# analysis
analysis1 = analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")]['cost_per_conv']
analysis1.index = (analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].date)
decompose_result_mult = seasonal_decompose(analysis1, model="additive",period =7)
plt.rcParams.update({'figure.figsize': (18,10)})
decompose_result_mult.plot()
plt.plot()
# Out:
# []

# %%
analysis[(analysis["date"]<"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="date", y = "final", figsize = (18,3))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
analysis["cost_per_conv"].max()
# Out:
# 508.12

# %%
analysis["cost_per_conv"].min()
# Out:
# 16.139565217391304

# %%
analysis["cost_per_conv"].mean()
# Out:
# 73.32647654400382

# %%
analysis["cost_per_conv"].expanding(1).quantile(0.80).shift()
# Out:
# 0             NaN
# 1       26.147193
# 2       33.024308
# 3       32.377853
# 4       37.241346
#           ...
# 182    110.081148
# 183    110.032539
# 184    109.983931
# 185    110.202291
# 186    110.492431
# Name: cost_per_conv, Length: 187, dtype: float64

# %%
analysis[(analysis["date"]>"22-04-01") & (analysis["date"]<"22-07-06")].plot(x="cost_per_conv", y = "co",ax=ax, secondary_y =True)

# %%
analysis[analysis["cost_per_conv"]<200]["cost_per_conv"].hist()
# Out:
# <AxesSubplot:>

# %%
analysis[analysis["final"]<200]["final"].hist()
# Out:
# <AxesSubplot:>

# %%
data1["keyword"].unique()
# Out:
# array(['hellofresh meal', 'hello fresh meal', 'hello fresh meals',
#        'hellofresh meals', 'hello fresh meal options',
#        'hello fresh meals cost', 'hello fresh meal kit',
#        'hello fresh meal plan', 'hello fresh meal kits',
#        'hellofresh meal cost', 'hello fresh meal plans',
#        'hellofresh meal kit cost', 'hellofresh meal prep',
#        'average cost of hellofresh meals', 'hello fresh meal cost',
#        'meal kit hello fresh', 'meal plans hello fresh',
#        'hello fresh meal deals', 'hellofresh meal plans cost',
#        'meal kits hello fresh', 'hello fresh meal subscription',
#        'meals hellofresh', 'meal plans hellofresh',
#        'hello fresh meal deal', 'hellofresh meal boxes',
#        'hellofresh meal price', 'meal kit hellofresh',
#        'meal kits hellofresh', 'hello fresh meals prepared',
#        'hello fresh meals deals', 'hellofresh meals frozen',
#        'hellofresh meals price', 'hellofresh meal pricing',
#        'hellofresh meal subscription', 'meal prep hellofresh'],
#       dtype=object)

# %%
analysis["conversions"].sum()
# Out:
# 7859.169999999999

# %%
analysis["cost"].sum()
# Out:
# 617474.33

# %%
analysis["cost_per_conv"].mean()
# Out:
# 73.32647654400382

# %%
analysis["cost"].sum()/analysis["conversions"].sum()
# Out:
# 78.56737161812252

# %%
analysis["final"].max()
# Out:
# 105.0

# %%
 analysis[analysis["cost_per_conv"]<250].plot(y= "conversions", x= "final", kind = "scatter",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='final', ylabel='conversions'>

# %%
 analysis[analysis["cost_per_conv"]<250].plot(y= "cost", x= "final", kind = "scatter",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='final', ylabel='cost'>

# %%
data1
# Out:
#           date  campaign_id   ad_group_id    keyword_id  \
# 0     22-01-01  10712349001  104499295183   38026285494
# 1     22-01-01  10712349001  104499295183   38825879769
# 2     22-01-01  10712349001  104499295183   57112105614
# 3     22-01-01  10712349001  104499295183   57112112094
# 4     22-01-01  10712349001  104499295183   57112114014
# ...        ...          ...           ...           ...
# 3532  22-07-06  10712349001  104499295183  429776484854
# 3533  22-07-06  10712349001  104499295183  430543157464
# 3534  22-07-06  10712349001  104499295183  430543157704
# 3535  22-07-06  10712349001  104499295183  430602999045
# 3536  22-07-06  10712349001  104499295183  818169429266
#
#                                keyword Match type Bidding strategy type  \
# 0                      hellofresh meal      Exact            Target CPA
# 1                     hello fresh meal      Exact            Target CPA
# 2                    hello fresh meals     Phrase            Target CPA
# 3                    hello fresh meals      Exact            Target CPA
# 4                     hellofresh meals      Exact            Target CPA
# ...                                ...        ...                   ...
# 3532               meal kit hellofresh      Exact            Target CPA
# 3533             meal kits hello fresh      Exact            Target CPA
# 3534            meal plans hello fresh      Exact            Target CPA
# 3535                  meals hellofresh      Exact            Target CPA
# 3536  average cost of hellofresh meals      Exact            Target CPA
#
#      Ad group name_x                                Campaign name_x  \
# 0              Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 1              Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 2              Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 3              Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 4              Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# ...              ...                                            ...
# 3532           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 3533           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 3534           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 3535           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 3536           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
#
#       impressions  ...  Search rank lost impression share  Lost impressions  \
# 0               5  ...                               0.00                 0
# 1              19  ...                               0.05                 1
# 2              41  ...                               0.73               105
# 3            2967  ...                               0.06               185
# 4             115  ...                               0.09                12
# ...           ...  ...                                ...               ...
# 3532            1  ...                                NaN                 0
# 3533            1  ...                                NaN                 0
# 3534            1  ...                                NaN                 0
# 3535            1  ...                                NaN                 0
# 3536            2  ...                                NaN                 0
#
#       Absolute top impression percentage  Lost impressions due to rank  \
# 0                                   0.80                             0
# 1                                   0.72                             1
# 2                                   0.42                           105
# 3                                   0.53                           185
# 4                                   0.52                            12
# ...                                  ...                           ...
# 3532                                1.00                             0
# 3533                                0.00                             0
# 3534                                1.00                             0
# 3535                                1.00                             0
# 3536                                1.00                             0
#
#       Estimated total conversion rate  initial  final  level  Campaign name_y  \
# 0                                1.33      NaN    NaN    NaN              NaN
# 1                                0.00      NaN    NaN    NaN              NaN
# 2                                1.11      NaN    NaN    NaN              NaN
# 3                                0.70      NaN    NaN    NaN              NaN
# 4                                0.39      NaN    NaN    NaN              NaN
# ...                               ...      ...    ...    ...              ...
# 3532                              NaN      NaN  105.0    NaN              NaN
# 3533                              NaN      NaN  105.0    NaN              NaN
# 3534                             0.00      NaN  105.0    NaN              NaN
# 3535                             0.00      NaN  105.0    NaN              NaN
# 3536                             0.00      NaN  105.0    NaN              NaN
#
#       Ad group name_y
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3532              NaN
# 3533              NaN
# 3534              NaN
# 3535              NaN
# 3536              NaN
#
# [3537 rows x 28 columns]

# %%
data1['weekday'] = pd.to_datetime(data1['date']).dt.day_name()
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
data1['weekday'] = pd.Categorical(data1['weekday'], categories=cats, ordered=True)

# %%
## for every action we have thing about impression shaare

# %%
analysis = data1[data1["date"]>"22-05-15"].groupby(["ad_group_id","date"])[['conversions','cost','impression_share']].agg({"conversions":"sum","cost":"sum","impression_share":"mean"}).reset_index()

analysis['weekday'] = pd.to_datetime(analysis['date']).dt.day_name()
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
analysis['weekday'] = pd.Categorical(analysis['weekday'], categories=cats, ordered=True)

# %%
analysis["cost_per_conv"] = analysis["cost"]/analysis["conversions"]

# %%
analysis =
# Out:
#      ad_group_id      date  conversions      cost  impression_share  \
# 0   104499295183  22-05-16        83.20   8279.34          0.902273
# 1   104499295183  22-05-17       216.42  16651.41          0.933333
# 2   104499295183  22-05-18        62.07   5270.59          0.936500
# 3   104499295183  22-05-19        52.71   5629.94          0.949500
# 4   104499295183  22-05-20        28.72   4224.13          0.945263
# 5   104499295183  22-05-21        48.12   5575.76          0.933333
# 6   104499295183  22-05-22        73.06   7082.65          0.937273
# 7   104499295183  22-05-23        57.56   5460.59          0.945000
# 8   104499295183  22-05-24        47.08   4726.91          0.913158
# 9   104499295183  22-05-25        49.58   5282.59          0.948000
# 10  104499295183  22-05-26        46.24   5109.17          0.891500
# 11  104499295183  22-05-27        54.29   4902.19          0.921667
# 12  104499295183  22-05-28        39.74   4936.28          0.903500
# 13  104499295183  22-05-29        42.06   4299.04          0.937826
# 14  104499295183  22-05-30        81.24   6221.29          0.940000
# 15  104499295183  22-05-31        49.16   5479.23          0.928696
# 16  104499295183  22-06-01        44.25   5193.61          0.954800
# 17  104499295183  22-06-02        52.06   7793.76          0.919600
# 18  104499295183  22-06-03        61.80   5948.95          0.913750
# 19  104499295183  22-06-04        50.82   6566.82          0.883913
# 20  104499295183  22-06-05        70.37   8889.46          0.938800
# 21  104499295183  22-06-06        83.19  10492.11          0.896538
# 22  104499295183  22-06-07        69.15   8698.04          0.906400
# 23  104499295183  22-06-08        49.46   7852.55          0.908800
# 24  104499295183  22-06-09        66.92   8988.16          0.949231
# 25  104499295183  22-06-10        57.95   6235.89          0.919200
# 26  104499295183  22-06-11        57.60   5863.06          0.917826
# 27  104499295183  22-06-12        66.91   7352.52          0.883636
# 28  104499295183  22-06-13        53.06   6765.91          0.933750
# 29  104499295183  22-06-14        46.40   4561.60          0.933182
# 30  104499295183  22-06-15        39.60   4831.74          0.894348
# 31  104499295183  22-06-16        42.11   5556.60          0.923913
# 32  104499295183  22-06-17        46.27   6053.99          0.879167
# 33  104499295183  22-06-18        44.24   5082.61          0.927368
# 34  104499295183  22-06-19        37.81   5015.50          0.924783
# 35  104499295183  22-06-20        50.60   6172.94          0.937917
# 36  104499295183  22-06-21        44.87   5023.92          0.887727
# 37  104499295183  22-06-22        47.54   4733.64          0.912857
# 38  104499295183  22-06-23        35.26   3977.97          0.927500
# 39  104499295183  22-06-24        38.05   4335.68          0.914783
# 40  104499295183  22-06-25        43.06   4349.83          0.927826
# 41  104499295183  22-06-26        59.18   6423.13          0.950833
# 42  104499295183  22-06-27        53.56   6205.27          0.908400
# 43  104499295183  22-06-28        47.71   6289.11          0.886522
# 44  104499295183  22-06-29        34.75   5711.80          0.920455
# 45  104499295183  22-06-30        52.44   6654.00          0.938696
# 46  104499295183  22-07-01        32.00   4384.07          0.905833
# 47  104499295183  22-07-02        54.85   5381.06          0.920909
# 48  104499295183  22-07-03        44.25   4652.05          0.874500
# 49  104499295183  22-07-04        32.65   3955.12          0.920435
# 50  104499295183  22-07-05        35.49   4877.44          0.933043
# 51  104499295183  22-07-06         1.00    508.12               NaN
#
#       weekday  cost_per_conv
# 0      Sunday      99.511298
# 1      Monday      76.940255
# 2     Tuesday      84.913646
# 3   Wednesday     106.809714
# 4      Friday     147.079735
# 5    Saturday     115.871987
# 6      Sunday      96.942924
# 7      Monday      94.867790
# 8   Wednesday     100.401657
# 9    Thursday     106.546793
# 10     Friday     110.492431
# 11   Saturday      90.296371
# 12     Monday     124.214394
# 13    Tuesday     102.212078
# 14  Wednesday      76.579148
# 15   Thursday     111.457079
# 16     Friday     117.369718
# 17   Saturday     149.707261
# 18     Sunday      96.261327
# 19    Tuesday     129.217237
# 20  Wednesday     126.324570
# 21   Thursday     126.122250
# 22     Friday     125.785105
# 23     Sunday     158.765669
# 24     Monday     134.312014
# 25    Tuesday     107.608110
# 26  Wednesday     101.789236
# 27     Friday     109.886713
# 28   Saturday     127.514323
# 29     Sunday      98.310345
# 30     Monday     122.013636
# 31  Wednesday     131.954405
# 32   Thursday     130.840501
# 33     Friday     114.887206
# 34   Saturday     132.650093
# 35     Monday     121.994862
# 36    Tuesday     111.966124
# 37  Wednesday      99.571729
# 38   Thursday     112.818208
# 39   Saturday     113.946912
# 40     Sunday     101.017882
# 41     Monday     108.535485
# 42    Tuesday     115.856423
# 43   Thursday     131.819535
# 44     Friday     164.368345
# 45   Saturday     126.887872
# 46     Sunday     137.002187
# 47     Monday      98.105014
# 48    Tuesday     105.131073
# 49   Thursday     121.136907
# 50     Friday     137.431389
# 51   Saturday     508.120000

# %%
temp =data1[data1["date"]=='22-07-04'].groupby("weekday")[["conversions", "cost", "impression_share","final"]].agg({"conversions":"sum","cost":"sum","impression_share":"mean", "final":"mean"}).reset_index()

temp["cost_per_conv"]= temp["cost"] /temp["conversions"]                                                    
                                                        
                                                        
                                                        
temp
# Out:
#      weekday  conversions     cost  impression_share  final  cost_per_conv
# 0     Monday         0.00     0.00               NaN    NaN            NaN
# 1    Tuesday         0.00     0.00               NaN    NaN            NaN
# 2  Wednesday         0.00     0.00               NaN    NaN            NaN
# 3   Thursday        32.65  3955.12          0.920435  105.0     121.136907
# 4     Friday         0.00     0.00               NaN    NaN            NaN
# 5   Saturday         0.00     0.00               NaN    NaN            NaN
# 6     Sunday         0.00     0.00               NaN    NaN            NaN

# %%
data1["final"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 3532    105.0
# 3533    105.0
# 3534    105.0
# 3535    105.0
# 3536    105.0
# Name: final, Length: 3537, dtype: float64

# %%
data1[data1['date'] == '22-06-15'][['conversions','cost']].sum()
# Out:
# conversions      39.60
# cost           4831.74
# dtype: float64
