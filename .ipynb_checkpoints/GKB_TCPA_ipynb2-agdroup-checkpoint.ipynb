# %%
import pandas as pd

# %%
datas = pd.read_csv('hello_fresh - Sheetmeal.csv')
# date = []
# # for i in range(len(datas["Date & time"])):
#     k =datas["Date & time"][i].split(",")[0].split()
#     k = k[2] + "-"+month_dict[k[1]]+"-" +k[0]
#     date.append(k)
  
# date

datas
datas = datas.rename({'Date & time':'date'}, axis = 1)
# datas["date"] = date
# datas = datas.drop(['Date & time'], axis=1)

# %%
# datas
# print(datas)

# %%
datas['date'] = pd.to_datetime(datas['date']).dt.strftime("%y-%m-%d")

# %%
# datas

# %%
# idx = pd.date_range('22-07-05', '09-30-2013')

# %%
def get_tcpa_range(data):

  initial = []
  final = []
  dates = []
  campaigns = []
  ad_group = []
  # data["Changes"]
  level = []
  # data["Date & time"]
  # print(type(data["Changes"]))
  for i in range(len(data["Changes"])):
    if "Target CPA" in data["Changes"][i]:
      # print(i)
      # print(data["Changes"][i])
      # print(data["Date & time"][i])
      dates.append(data["date"][i])
      campaigns.append(data["Campaign"][i])
      ad_group.append(data["Ad group"][i])
      

    
      if "Campaign" in data["Changes"][i]:
        level.append("campaign")

      else:
        level.append("ad group")
    
      # print((i))
      k = data["Changes"][i].split(" ")
      # print(i)
    
      for j in k:
        if "to" == j:
          initial.append(float(k[k.index(j)-1].replace("$","")))
          final.append(float(k[k.index(j)+1].replace("$","")))
        
    
  df= pd.DataFrame()
  df["date"]= dates
  df["initial"] = initial
  df["final"] = final
  df["level"] = level
  df["Campaign name"]= campaigns
  df["Ad group name"] = ad_group
  
  return df

# %%
tcpa = get_tcpa_range(datas)
df= tcpa 
# df
tcpa
# Out:
#         date  initial  final     level  \
# 0   22-07-05    120.0  126.0  ad group
# 1   22-07-04    111.0  120.0  ad group
# 2   22-06-28     99.0  105.0  campaign
# 3   22-06-03    107.0  111.0  ad group
# 4   22-06-03     99.0  107.0  ad group
# 5   22-05-31     95.0   99.0  campaign
# 6   22-05-17    105.0   95.0  campaign
# 7   22-05-17     95.0  105.0  campaign
# 8   22-05-17     93.0   95.0  campaign
# 9   22-05-14     80.0   93.0  campaign
# 10  22-05-10     85.0   80.0  campaign
# 11  22-04-30     93.0   99.0  ad group
# 12  22-04-27     90.0   85.0  campaign
# 13  22-04-23     85.0   90.0  campaign
# 14  22-04-21     80.0   85.0  campaign
# 15  22-04-20     85.0   93.0  ad group
# 16  22-04-18     83.0   85.0  ad group
# 17  22-04-17     75.0   83.0  ad group
# 18  22-04-17     55.0   75.0  ad group
# 19  22-04-16     51.0   55.0  ad group
# 20  22-04-12     36.0   51.0  ad group
# 21  22-03-31     70.0   80.0  campaign
# 22  22-02-15     50.0   70.0  campaign
# 23  22-01-10     75.0   50.0  campaign
#
#                                     Campaign name Ad group name
# 0   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 1   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 2   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 3   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 4   US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 5   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 6   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 7   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 8   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 9   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 10  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 11  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 12  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 13  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 14  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 15  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 16  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 17  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 18  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 19  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 20  US-S[01]: Prospecting | Brand | Meals - Exact         Meals
# 21  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 22  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 23  US-S[01]: Prospecting | Brand | Meals - Exact           NaN

# %%
# from datetime import datetime
# idx = pd.date_range(start="2022-01-10",end="2022-02-15")
# print(idx)

# %%
# datas

# %%
data = pd.read_csv('TCPA strategy - Hellofresh-metric.csv')
data.rename(columns={'Date':'date','Ad group ID':'ad_group_id','Campaign ID':'campaign_id','Cost':'cost','Keyword ID':'keyword_id','Cost per conversion':'cost_per_conversion','Conversions':'conversions','Clicks':'clicks','Impressions':'impressions','Impression share':'impression_share','Keyword':'keyword'},inplace=True)
# print(data.head())
# print("no of DATE", len(data["date"].unique()))
# print("no of campaign_id", len(data["campaign_id"].unique()))
# print("no of ad_group_id", len(data["ad_group_id"].unique()))
26536744623
# print(len(data["target_cpa"].unique()))
# print(data["target_cpa"].unique())

data_meals = data[data["Campaign name"]== "US-S[01]: Prospecting | Brand | Meals - Exact"].copy()
data_meals['date'] = pd.to_datetime(data_meals['date']).dt.strftime("%y-%m-%d")
# data_meals
# data_meals["clicks"]

# %%
# tcpa
tcpa = tcpa[tcpa["level"]== "campaign"]
tcpa
# Out:
#         date  initial  final     level  \
# 2   22-06-28     99.0  105.0  campaign
# 5   22-05-31     95.0   99.0  campaign
# 6   22-05-17    105.0   95.0  campaign
# 7   22-05-17     95.0  105.0  campaign
# 8   22-05-17     93.0   95.0  campaign
# 9   22-05-14     80.0   93.0  campaign
# 10  22-05-10     85.0   80.0  campaign
# 12  22-04-27     90.0   85.0  campaign
# 13  22-04-23     85.0   90.0  campaign
# 14  22-04-21     80.0   85.0  campaign
# 21  22-03-31     70.0   80.0  campaign
# 22  22-02-15     50.0   70.0  campaign
# 23  22-01-10     75.0   50.0  campaign
#
#                                     Campaign name Ad group name
# 2   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 5   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 6   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 7   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 8   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 9   US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 10  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 12  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 13  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 14  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 21  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 22  US-S[01]: Prospecting | Brand | Meals - Exact           NaN
# 23  US-S[01]: Prospecting | Brand | Meals - Exact           NaN

# %%
data1 = pd.merge(data_meals,tcpa,on=['date'], how = "left")
data1["final"].fillna(method ="ffill", inplace = True)
# df.fillna(method='ffill')

# data["ad_group_id"].unique()
# print(data.groupby(["date"])["initial"])
# data[data["date"]>="22-01-8"][["date","final"]].head(60)
# data[data["final"]==50]["date"]

# %%
# data.fillna(0,inplace=True)
# data = data[data["level"] == "campaign" ]

data1["Bidding strategy type"].unique()
# Out:
# array(['Target CPA'], dtype=object)

# %%
count = 0
for i in tcpa['final']:
  count = count+1
  # print(i)
  data = data1[data1["final"] == i]
  # print(data)
  #find top ad_groups basis spends
  analysis = data.groupby(['ad_group_id'])['cost'].sum().reset_index().sort_values('cost',ascending=False,ignore_index = True)
  analysis["Cost_cumsum"] = analysis["cost"].cumsum()
  analysis["cost_share"] = analysis["cost"].cumsum()/analysis['cost'].sum()


  #take top 10 adgroups
  top_adgroups = analysis[:10]['ad_group_id'].values
  # print(top_adgroups)


  df = data[data['ad_group_id'].isin(top_adgroups)].copy()

  analysis = df.groupby('ad_group_id')[['final','cost','conversions','impression_share',"clicks"]].agg({'final':'mean','cost':'sum','conversions':'sum','impression_share':'mean',"clicks":"sum",})
  analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']
  if count == 1:
    new = analysis
  new = pd.concat([new, analysis])
new = new.iloc[1:,:]
print(new)
# Out:
#               final       cost  conversions  impression_share  clicks  \
# ad_group_id
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   99.0  174444.49      1461.25          0.918219   35849
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183   93.0   23347.30       226.59          0.914348    4407
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   90.0   24564.24       237.55          0.887821    5427
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   70.0   49320.80      1290.68          0.756044   27953
# 104499295183   50.0   29763.93       912.44          0.816783   22565
#
#               cost_per_conv
# ad_group_id
# 104499295183     117.764781
# 104499295183     119.380318
# 104499295183      96.549223
# 104499295183     117.764781
# 104499295183      96.549223
# 104499295183     103.037645
# 104499295183      75.317866
# 104499295183     103.061015
# 104499295183     103.406609
# 104499295183     103.061015
# 104499295183      75.317866
# 104499295183      38.213035
# 104499295183      32.620150

# %%
new
# Out:
#               final       cost  conversions  impression_share  clicks  \
# ad_group_id
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   99.0  174444.49      1461.25          0.918219   35849
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183   93.0   23347.30       226.59          0.914348    4407
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   90.0   24564.24       237.55          0.887821    5427
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   70.0   49320.80      1290.68          0.756044   27953
# 104499295183   50.0   29763.93       912.44          0.816783   22565
#
#               cost_per_conv
# ad_group_id
# 104499295183     117.764781
# 104499295183     119.380318
# 104499295183      96.549223
# 104499295183     117.764781
# 104499295183      96.549223
# 104499295183     103.037645
# 104499295183      75.317866
# 104499295183     103.061015
# 104499295183     103.406609
# 104499295183     103.061015
# 104499295183      75.317866
# 104499295183      38.213035
# 104499295183      32.620150

# %%
 new["cost_per_conv_delta"] = new["cost_per_conv"].diff() 
 new["clicks_delta"] = new["clicks"].diff()
 new["impression_share_delta"] = new["impression_share"].diff()
new["conversions_delta"] = new["conversions"].diff()
new
# Out:
#               final       cost  conversions  impression_share  clicks  \
# ad_group_id
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   99.0  174444.49      1461.25          0.918219   35849
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183  105.0   47963.24       407.28          0.915174   10506
# 104499295183   95.0   79822.07       826.75          0.931355   17011
# 104499295183   93.0   23347.30       226.59          0.914348    4407
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   90.0   24564.24       237.55          0.887821    5427
# 104499295183   85.0   94032.87       912.40          0.917130   19107
# 104499295183   80.0   70070.47       930.33          0.830903   20497
# 104499295183   70.0   49320.80      1290.68          0.756044   27953
# 104499295183   50.0   29763.93       912.44          0.816783   22565
#
#               cost_per_conv  cost_per_conv_delta  clicks_delta  \
# ad_group_id
# 104499295183     117.764781                  NaN           NaN
# 104499295183     119.380318             1.615537       25343.0
# 104499295183      96.549223           -22.831095      -18838.0
# 104499295183     117.764781            21.215558       -6505.0
# 104499295183      96.549223           -21.215558        6505.0
# 104499295183     103.037645             6.488422      -12604.0
# 104499295183      75.317866           -27.719779       16090.0
# 104499295183     103.061015            27.743149       -1390.0
# 104499295183     103.406609             0.345594      -13680.0
# 104499295183     103.061015            -0.345594       13680.0
# 104499295183      75.317866           -27.743149        1390.0
# 104499295183      38.213035           -37.104831        7456.0
# 104499295183      32.620150            -5.592885       -5388.0
#
#               impression_share_delta  conversions_delta
# ad_group_id
# 104499295183                     NaN                NaN
# 104499295183                0.003045            1053.97
# 104499295183                0.013136            -634.50
# 104499295183               -0.016181            -419.47
# 104499295183                0.016181             419.47
# 104499295183               -0.017007            -600.16
# 104499295183               -0.083445             703.74
# 104499295183                0.086227             -17.93
# 104499295183               -0.029309            -674.85
# 104499295183                0.029309             674.85
# 104499295183               -0.086227              17.93
# 104499295183               -0.074859             360.35
# 104499295183                0.060739            -378.24

# %%
#grpah plot for this 

new.plot(x='final',y='cost_per_conv',figsize=(18,3))

new.plot(x='final',y='conversions',figsize=(18,3))
new.plot(x='final',y='cost',figsize=(18,3))
new.plot(x='final',y='impression_share',figsize=(18,3))
# Out:
# <AxesSubplot:xlabel='final'>

# %%
# df["date"]
# analysis
# new.plot(x='date',y='cost_per_conv',figsize=(18,3))

# %%
new.plot(x='cost_per_conv',y='conversions',figsize=(18,3))

new.plot(x='final',y='conversions',figsize=(18,3))
new.plot(x='cost',y='conversions',figsize=(18,3))
new.plot(x='impression_share',y='conversions',figsize=(18,3))
# Out:
# <AxesSubplot:xlabel='impression_share'>

# %%
new.plot(y="cost_per_conv", x="clicks", kind = "scatter")
new.plot(y="cost_per_conv", x="impression_share", kind = "scatter")
new.plot(x="impression_share", y="clicks", kind = "line")
new.plot(y="cost_per_conv", x="conversions", kind = "scatter")
new.plot(y="cost_per_conv", x="clicks", kind = "line")
new.plot(y="cost_per_conv", x="impression_share", kind = "line")
new.plot(y="cost_per_conv", x="conversions", kind = "line")
# Out:
# <AxesSubplot:xlabel='conversions'>

# %%
new.plot(x="cost_per_conv_delta", y="clicks_delta", kind = "bar")
new.plot(y="cost_per_conv_delta", x="clicks_delta", kind = "scatter")
new.plot(x="cost_per_conv_delta", y="clicks_delta", kind = "line")

# new.plot(x="cost_per_conv_delta", y="impression_share", kind = "scatter")
# new.plot(x="cost_per_conv_delta", y="conversions", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='cost_per_conv_delta'>

# %%
new.plot(x="cost_per_conv_delta", y="impression_share_delta", kind = "bar")
new.plot(y="cost_per_conv_delta", x="impression_share_delta", kind = "scatter")
new.plot(x="cost_per_conv_delta", y="impression_share_delta", kind = "line")
# Out:
# <AxesSubplot:xlabel='cost_per_conv_delta'>

# %%
new.plot(x="cost_per_conv_delta", y="conversions_delta", kind = "bar")
new.plot(x="cost_per_conv_delta", y="conversions_delta", kind = "scatter")
new.plot(x="cost_per_conv_delta", y="conversions_delta", kind = "line")
# Out:
# <AxesSubplot:xlabel='cost_per_conv_delta'>

# %%
data = data1[data1["final"] == 70]

# %%
#find top ad_groups basis spends
analysis = data.groupby(['ad_group_id'])['cost'].sum().reset_index().sort_values('cost',ascending=False,ignore_index = True)
analysis["Cost_cumsum"] = analysis["cost"].cumsum()
analysis["cost_share"] = analysis["cost"].cumsum()/analysis['cost'].sum()

# %%
analysis
# Out:
#     ad_group_id     cost  Cost_cumsum  cost_share
# 0  104499295183  49320.8      49320.8         1.0

# %%
#take top 10 adgroups
top_adgroups = analysis[:10]['ad_group_id'].values
print(top_adgroups)
# Out:
# [104499295183]

# %%
df = data[data['ad_group_id'].isin(top_adgroups)].copy()
df
# Out:
#           date  campaign_id   ad_group_id     keyword_id  \
# 693   22-02-15  10712349001  104499295183    38026285494
# 694   22-02-15  10712349001  104499295183    38825879769
# 695   22-02-15  10712349001  104499295183    57112105614
# 696   22-02-15  10712349001  104499295183    57112112094
# 697   22-02-15  10712349001  104499295183    57112114014
# ...        ...          ...           ...            ...
# 1418  22-03-30  10712349001  104499295183   430602999045
# 1419  22-03-30  10712349001  104499295183   441855977027
# 1420  22-03-30  10712349001  104499295183   459206352647
# 1421  22-03-30  10712349001  104499295183   818169429266
# 1422  22-03-30  10712349001  104499295183  1170995176309
#
#                                keyword Match type Bidding strategy type  \
# 693                    hellofresh meal      Exact            Target CPA
# 694                   hello fresh meal      Exact            Target CPA
# 695                  hello fresh meals     Phrase            Target CPA
# 696                  hello fresh meals      Exact            Target CPA
# 697                   hellofresh meals      Exact            Target CPA
# ...                                ...        ...                   ...
# 1418                  meals hellofresh      Exact            Target CPA
# 1419             hellofresh meal price      Exact            Target CPA
# 1420              hellofresh meal prep      Exact            Target CPA
# 1421  average cost of hellofresh meals      Exact            Target CPA
# 1422             hello fresh meal cost     Phrase            Target CPA
#
#      Ad group name_x                                Campaign name_x  \
# 693            Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 694            Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 695            Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 696            Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 697            Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# ...              ...                                            ...
# 1418           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 1419           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 1420           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 1421           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
# 1422           Meals  US-S[01]: Prospecting | Brand | Meals - Exact
#
#       impressions  ...  Search rank lost impression share  Lost impressions  \
# 693             6  ...                               0.25                 2
# 694            14  ...                               0.00                 0
# 695            30  ...                               0.64                52
# 696          1260  ...                               0.15               206
# 697            42  ...                               0.23                12
# ...           ...  ...                                ...               ...
# 1418            1  ...                               0.00                 0
# 1419            1  ...                               0.00                 0
# 1420            1  ...                               0.50                 1
# 1421            5  ...                               0.00                 0
# 1422            4  ...                               0.81                17
#
#       Absolute top impression percentage  Lost impressions due to rank  \
# 693                                 0.17                             2
# 694                                 0.21                             0
# 695                                 0.24                            52
# 696                                 0.18                           206
# 697                                 0.29                            12
# ...                                  ...                           ...
# 1418                                0.00                             0
# 1419                                0.00                             0
# 1420                                0.00                             1
# 1421                                0.60                             0
# 1422                                0.00                            17
#
#       Estimated total conversion rate  initial  final     level  \
# 693                              0.00     50.0   70.0  campaign
# 694                              0.00     50.0   70.0  campaign
# 695                              0.00     50.0   70.0  campaign
# 696                              0.29     50.0   70.0  campaign
# 697                              0.86     50.0   70.0  campaign
# ...                               ...      ...    ...       ...
# 1418                              NaN      NaN   70.0       NaN
# 1419                              NaN      NaN   70.0       NaN
# 1420                              NaN      NaN   70.0       NaN
# 1421                             3.43      NaN   70.0       NaN
# 1422                              NaN      NaN   70.0       NaN
#
#                                     Campaign name_y  Ad group name_y
# 693   US-S[01]: Prospecting | Brand | Meals - Exact              NaN
# 694   US-S[01]: Prospecting | Brand | Meals - Exact              NaN
# 695   US-S[01]: Prospecting | Brand | Meals - Exact              NaN
# 696   US-S[01]: Prospecting | Brand | Meals - Exact              NaN
# 697   US-S[01]: Prospecting | Brand | Meals - Exact              NaN
# ...                                             ...              ...
# 1418                                            NaN              NaN
# 1419                                            NaN              NaN
# 1420                                            NaN              NaN
# 1421                                            NaN              NaN
# 1422                                            NaN              NaN
#
# [730 rows x 28 columns]

# %%
#no of keywords in those adgroups
df.groupby('ad_group_id')['keyword_id'].nunique()
# Out:
# ad_group_id
# 104499295183    29
# Name: keyword_id, dtype: int64

# %%
analysis = df.groupby('ad_group_id')[['final','cost','conversions','impression_share']].agg({'final':'mean','cost':'sum','conversions':'sum','impression_share':'mean'})
analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']

# %%
analysis
# Out:
#               final      cost  conversions  impression_share  cost_per_conv
# ad_group_id
# 104499295183   50.0  29763.93       912.44          0.816783       32.62015

# %%
ad_group_id = 104499295183
analysis = df.groupby(['date','ad_group_id'])[['cost','conversions','final','clicks','impressions','impression_share']].agg({'cost':'sum','conversions':'sum','final':'mean','clicks':'sum','impressions':'sum','impression_share':'mean'}).reset_index()
# print(analysis)
analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']
analysis['cost_per_click'] = analysis['cost']/analysis['clicks']
analysis['cvr'] = analysis['conversions']/analysis['clicks']
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='cost_per_conv',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='final',figsize=(18,3),ax=ax)
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='conversions',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='cost_per_click',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='cvr',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='impressions',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='impression_share',figsize=(18,3))

# %% [markdown]
# # analysis for some time date for differnt tcpa

# %%
# data1["final"]

analysis = data1.groupby(['date','ad_group_id'])[['cost','conversions','final','clicks','impressions','impression_share']].agg({'cost':'sum','conversions':'sum','final':'mean','clicks':'sum','impressions':'sum','impression_share':'mean'}).reset_index()
analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']

# %%
tcpa['final']
# Out:
# 2     105.0
# 5      99.0
# 6      95.0
# 7     105.0
# 8      95.0
# 9      93.0
# 10     80.0
# 12     85.0
# 13     90.0
# 14     85.0
# 21     80.0
# 22     70.0
# 23     50.0
# Name: final, dtype: float64

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "clicks", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "conversions", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "cost_per_conv", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(x= "date", y= "impression_share", kind = "line",figsize=(10,5),title = i)

# %%
count = 0
for i in tcpa['final']:
    count = count +1
    if count <=5:
        analysis[analysis["final"]==i].plot(y= "cost_per_conv", x= "impression_share", kind = "scatter",figsize=(10,5),title = i)

# %%
 analysis.plot(y= "cost_per_conv", x= "impression_share", kind = "scatter",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='impression_share', ylabel='cost_per_conv'>

# %%
 analysis.plot(y= "cost_per_conv", x= "clicks", kind = "scatter",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='clicks', ylabel='cost_per_conv'>

# %%
 analysis.plot(y= "cost_per_conv", x= "conversions", kind = "scatter",figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='conversions', ylabel='cost_per_conv'>

# %%
 analysis.plot(y= "cost_per_conv", x= "final", kind = "scatter",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='final', ylabel='cost_per_conv'>

# %%
ad_group_id = 104499295183
analysis = df.groupby(['date','ad_group_id'])[['cost','conversions','final','clicks','impressions','impression_share']].agg({'cost':'sum','conversions':'sum','final':'mean','clicks':'sum','impressions':'sum','impression_share':'mean'}).reset_index()
print(analysis)
analysis['cost_per_conv'] = analysis['cost']/analysis['conversions']
analysis['cost_per_click'] = analysis['cost']/analysis['clicks']
analysis['cvr'] = analysis['conversions']/analysis['clicks']
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='cost_per_conv',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='final',figsize=(18,3),ax=ax)
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='conversions',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='cost_per_click',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='cvr',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='impressions',figsize=(18,3))
ax = analysis[analysis['ad_group_id'] == ad_group_id].plot(x='date',y='impression_share',figsize=(18,3))
# Out:
#         date   ad_group_id     cost  conversions  final  clicks  impressions  \
# 0   22-02-15  104499295183   484.00         8.00   70.0     477         1451
# 1   22-02-16  104499295183   439.26        14.50   70.0     420         1392
# 2   22-02-17  104499295183   436.53        13.06   70.0     407         1267
# 3   22-02-18  104499295183   302.19        16.00   70.0     282          999
# 4   22-02-19  104499295183   371.21        23.00   70.0     341         1231
# 5   22-02-20  104499295183   310.45        12.04   70.0     288         1175
# 6   22-02-21  104499295183   682.72        27.04   70.0     484         1740
# 7   22-02-22  104499295183  1070.83        39.00   70.0     759         2659
# 8   22-02-23  104499295183   958.52        40.46   70.0     754         2719
# 9   22-02-24  104499295183   900.95        26.04   70.0     604         2361
# 10  22-02-25  104499295183   951.18        26.04   70.0     576         2059
# 11  22-02-26  104499295183  1188.59        31.00   70.0     629         2171
# 12  22-02-27  104499295183  1328.03        46.00   70.0     731         2531
# 13  22-02-28  104499295183   884.89        16.00   70.0     403         1352
# 14  22-03-01  104499295183   776.86        18.54   70.0     358         1334
# 15  22-03-02  104499295183   825.54        25.00   70.0     417         1533
# 16  22-03-03  104499295183   874.59        17.04   70.0     392         1466
# 17  22-03-04  104499295183  1085.87        26.04   70.0     497         1775
# 18  22-03-05  104499295183  1155.47        31.05   70.0     592         2342
# 19  22-03-06  104499295183  1537.09        28.53   70.0     742         2911
# 20  22-03-07  104499295183  1571.79        32.00   70.0     721         2766
# 21  22-03-08  104499295183  1301.96        23.03   70.0     677         2572
# 22  22-03-09  104499295183  1313.98        24.00   70.0     701         2545
# 23  22-03-10  104499295183  1244.21        34.03   70.0     613         2126
# 24  22-03-11  104499295183  1107.65        20.41   70.0     536         1876
# 25  22-03-12  104499295183  1595.80        33.00   70.0     816         2591
# 26  22-03-13  104499295183  1637.13        39.03   70.0     791         2504
# 27  22-03-14  104499295183  1759.17        26.59   70.0     917         2635
# 28  22-03-15  104499295183  1579.95        30.42   70.0     788         2535
# 29  22-03-16  104499295183  1389.92        37.00   70.0     796         2451
# 30  22-03-17  104499295183  1158.19        40.03   70.0     692         2243
# 31  22-03-18  104499295183   971.36        33.09   70.0     580         1950
# 32  22-03-19  104499295183  1330.93        21.33   70.0     713         2380
# 33  22-03-20  104499295183  1469.60        41.65   70.0     822         2582
# 34  22-03-21  104499295183  1644.38        46.66   70.0     873         2707
# 35  22-03-22  104499295183  1349.02        39.85   70.0     884         2838
# 36  22-03-23  104499295183  1513.07        42.16   70.0     869         2555
# 37  22-03-24  104499295183  1110.32        36.02   70.0     745         2312
# 38  22-03-25  104499295183   874.54        29.04   70.0     569         1814
# 39  22-03-26  104499295183   952.85        34.00   70.0     562         1906
# 40  22-03-27  104499295183  1226.26        41.54   70.0     725         2387
# 41  22-03-28  104499295183  1317.30        35.05   70.0     771         2324
# 42  22-03-29  104499295183  1526.03        35.73   70.0     813         2290
# 43  22-03-30  104499295183  1810.62        30.64   70.0     826         2318
#
#     impression_share
# 0           0.795385
# 1           0.781111
# 2           0.765000
# 3           0.710000
# 4           0.762857
# 5           0.688667
# 6           0.740000
# 7           0.777143
# 8           0.691333
# 9           0.769444
# 10          0.801765
# 11          0.750625
# 12          0.708235
# 13          0.770000
# 14          0.709412
# 15          0.704375
# 16          0.834286
# 17          0.778235
# 18          0.704118
# 19          0.770000
# 20          0.602000
# 21          0.715789
# 22          0.723529
# 23          0.750667
# 24          0.798824
# 25          0.771667
# 26          0.797895
# 27          0.816667
# 28          0.827333
# 29          0.744118
# 30          0.732500
# 31          0.825000
# 32          0.745625
# 33          0.716111
# 34          0.735294
# 35          0.748095
# 36          0.759444
# 37          0.741176
# 38          0.733125
# 39          0.770000
# 40          0.805789
# 41          0.772632
# 42          0.805294
# 43          0.793889

# %%
df[df['ad_group_id'] == ad_group_id]['keyword'].unique()
# Out:
# array(['hellofresh meal', 'hello fresh meal', 'hello fresh meals',
#        'hellofresh meals', 'hello fresh meal options',
#        'hello fresh meals cost', 'hello fresh meal kit',
#        'hello fresh meal plan', 'hello fresh meal kits',
#        'hellofresh meal cost', 'hello fresh meal plans',
#        'meal kit hello fresh', 'meals hellofresh',
#        'hellofresh meal kit cost', 'hellofresh meal prep',
#        'hello fresh meal cost', 'meal plans hellofresh',
#        'hellofresh meal plans cost', 'hello fresh meal subscription',
#        'average cost of hellofresh meals', 'meal kits hello fresh',
#        'hello fresh meal deal', 'meal plans hello fresh',
#        'hellofresh meal boxes', 'hello fresh meal deals',
#        'hellofresh meal price', 'meal kit hellofresh',
#        'meal kits hellofresh'], dtype=object)
